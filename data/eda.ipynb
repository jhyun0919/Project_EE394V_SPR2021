# %%
from eda_tools import *

# %%
test_cases = [
    "pglib_opf_case24_ieee_rts.m",
    "pglib_opf_case30_ieee.m",
    "pglib_opf_case39_epri.m",
    "pglib_opf_case57_ieee.m",
    "pglib_opf_case73_ieee_rts.m",
    "pglib_opf_case89_pegase.m",
    "pglib_opf_case118_ieee.m",
    "pglib_opf_case162_ieee_dtc.m",
    "pglib_opf_case179_goc.m",
    "pglib_opf_case200_activ.m",
    "pglib_opf_case240_pserc.m",
    "pglib_opf_case300_ieee.m",
    "pglib_opf_case500_goc.m",
    "pglib_opf_case588_sdet.m",
    "pglib_opf_case793_goc.m",
    "pglib_opf_case1354_pegase.m",
    "pglib_opf_case1888_rte.m",
    "pglib_opf_case1951_rte.m",
    "pglib_opf_case2000_goc.m",
    "pglib_opf_case2312_goc.m",
    "pglib_opf_case2383wp_k.m",
    "pglib_opf_case2736sp_k.m",
    "pglib_opf_case2737sop_k.m",
    "pglib_opf_case2742_goc.m",
    "pglib_opf_case2746wop_k.m",
    "pglib_opf_case2746wop_k.m",
    "pglib_opf_case2848_rte.m",
]

dataset_size = 100
std_scaler = 0.05

# %%
idx = 0

case_name = test_cases[idx].split(".")[0]

infile = open(
    './size_' + str(dataset_size) + '/std_' + str(std_scaler) + '/' +
    case_name + '.pickle', 'rb')
dataset = pickle.load(infile)
infile.close()

X = dataset['x']
Y = dataset['y']
G = dataset['g']

df_X = pd.DataFrame(X)
df_Y = pd.DataFrame(Y)

print("> case: {}".format(test_cases[idx]))
show_info(G, df_X, df_Y)
# Out:
# > case: pglib_opf_case24_ieee_rts.m

# %%
dataset_size = 100
std_scaler_1 = 0.05
std_scaler_2 = 0.07

compare_dist_Ys_diff_std_scalers(test_cases, dataset_size, std_scaler_1,
                                 std_scaler_2)

# %%
dataset_size = 100
std_scaler = 0.05
test_type_1 = 'default'
test_type_2 = 'api'

compare_dist_Ys_diff_test_types(test_cases, dataset_size, std_scaler,
                                test_type_1, test_type_2)
